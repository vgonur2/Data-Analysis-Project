# %% [markdown]
# # STAT207 Mini-Project #1:
#
# # How does the nature of the relationship between 'Max Players' and 'Length of the main story' change for different values of 'publishers' in the dataset?
#
#
# Vishruth Gonur

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The research question I intend to explore is, "How does the nature of the relationship between 'Max Players' and 'Length of the main story' change for different values of 'publishers' in the dataset?"
#
# The reason I want to research this particular question is because, I assume certain publishers make their games longer than others. The same can be said about multiplayer support. The difference between these features I feel like is dependent on the publisher.
#
# I feel like people who want to find new video games to play, can look at the results of this project and see, which publisher makes their games longer, and which publishers like multiplayer functionality. Since a lot of people value story length in games, and the ability of playing with their freinds, they can either avoid or look into certain publishers to see what best matches their needs.

# %% [markdown]
# ## 2. Dataset Discussion

# %% [markdown]
# The dataset I am using is called, "video_games.csv" and is the default dataset that came with the project, and the link to this dataset is, "https://corgis-edu.github.io/corgis/csv/video_games/", this dataset was downloaded on 2/17/2025
#
# Each row in the dataset represents a singular video game published through the years of 2004-2010, and all their data such as publisher, time to complete main story and etc.
#
# About half of the data was collected through public information, such as if the game was licensed or not, or the Publisher of the game. However the other half of the data in the dataset was collected through croud sourcing. Varaibles such as Main Story average, and Main Story median, was collected through croud sourcing data and then averaged out, and inputted into the dataset.
#
# This dataset is inclusive of all possible observations, and I do not think any variable is left out. There are over 40 variables in this dataset each maticulously every part of a published video game, from everything to certain aspects about the video game like singleplayer or multiplayer or their score on a rating website.
#
# Depending on the answer to my research question, a person might make decisions such as choosing one publisher over the other, becuase they may prefer certain charecteristics of a video game. And if these charecteristics change dependent over the publisher, then people may support one publishers work more.
#
# The three variables I am exploring is the max players of the game at a time, the length of the main story, and publisher. The max players represent the number of players who can play at a time. The length of the main story represents the amount of time it takes to finish the main story of the game. And the publisher represents what company made the game.

# %%
df = pd.read_csv("video_games.csv")

# %%
df.head()
# Out:
#                       Title  Features.Handheld?  Features.Max Players  \
# 0         Super Mario 64 DS                True                     1
# 1    Lumines: Puzzle Fusion                True                     1
# 2        WarioWare Touched!                True                     2
# 3  Hot Shots Golf: Open Tee                True                     1
# 4              Spider-Man 2                True                     1
#
#    Features.Multiplatform?  Features.Online?                 Metadata.Genres  \
# 0                     True              True                          Action
# 1                     True              True                        Strategy
# 2                     True              True  Action,Racing / Driving,Sports
# 3                     True              True                          Sports
# 4                     True              True                          Action
#
#    Metadata.Licensed? Metadata.Publishers  Metadata.Sequel?  \
# ...

# %%
df.shape[0]
# Out:
# 1212

# %% [markdown]
# ## 3. Dataset Cleaning

# %%
df.isna().sum()
# Out:
# Title                              0
# Features.Handheld?                 0
# Features.Max Players               0
# Features.Multiplatform?            0
# Features.Online?                   0
# Metadata.Genres                    0
# Metadata.Licensed?                 0
# Metadata.Publishers              264
# Metadata.Sequel?                   0
# Metrics.Review Score               0
# Metrics.Sales                      0
# Metrics.Used Price                 0
# Release.Console                    0
# Release.Rating                     0
# Release.Re-release?                0
# Release.Year                       0
# Length.All PlayStyles.Average      0
# Length.All PlayStyles.Leisure      0
# Length.All PlayStyles.Median       0
# Length.All PlayStyles.Polled       0
# Length.All PlayStyles.Rushed       0
# Length.Completionists.Average      0
# Length.Completionists.Leisure      0
# Length.Completionists.Median       0
# Length.Completionists.Polled       0
# ...

# %% [markdown]
# The first thing I did, was do "isna().sum()" becuase this will give me the number of "na" values for each coulumn, and as we can see we had 264 na values for Metadata.Publishers, as a result of this, we needed to drop all na values

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Title                            0
# Features.Handheld?               0
# Features.Max Players             0
# Features.Multiplatform?          0
# Features.Online?                 0
# Metadata.Genres                  0
# Metadata.Licensed?               0
# Metadata.Publishers              0
# Metadata.Sequel?                 0
# Metrics.Review Score             0
# Metrics.Sales                    0
# Metrics.Used Price               0
# Release.Console                  0
# Release.Rating                   0
# Release.Re-release?              0
# Release.Year                     0
# Length.All PlayStyles.Average    0
# Length.All PlayStyles.Leisure    0
# Length.All PlayStyles.Median     0
# Length.All PlayStyles.Polled     0
# Length.All PlayStyles.Rushed     0
# Length.Completionists.Average    0
# Length.Completionists.Leisure    0
# Length.Completionists.Median     0
# Length.Completionists.Polled     0
# Length.Completionists.Rushed     0
# Length.Main + Extras.Average     0
# ...

# %%
df.shape[0]
# Out:
# 948

# %% [markdown]
# The code above basically goes through how we removed the na values, we did .dropna() to drop all na values, and redid df.isna().sum() to confirm the values actually got dropped, this left us with 948 rows (dropped 264 rows) as we can see in the third code box.
#
# One caveat with the method we used is that it dropped all values the computer deemed as na, however, there might be implicit na values that we wont know are na values such as "MISSING" or "Not Found", these values are not found and recongnized by the computer, and becuase the dataset is so large that we can not comb through it by hand, we can not find implicit na values.

# %%
pub_counts = df["Metadata.Publishers"].value_counts()

# %%
pub_counts >= 10
# Out:
# Metadata.Publishers
# EA                       True
# Ubisoft                  True
# Activision               True
# Nintendo                 True
# Sega                     True
# THQ                      True
# Sony                     True
# 2K                       True
# Konami                   True
# Capcom                   True
# Namco                    True
# SquareEnix               True
# Midway                   True
# Eidos                    True
# Microsoft                True
# Atari                    True
# Rockstar                 True
# Disney                   True
# Atari,Namco             False
# Nintendo,Sega           False
# Sony,Ubisoft            False
# Namco,Sony              False
# EA,Namco                False
# Capcom,Rockstar         False
# Nintendo,SquareEnix     False
# EA,Sony                 False
# Microsoft,SquareEnix    False
# Activision,Sony         False
# Capcom,Nintendo         False
# Activision,Konami       False
# ...

# %%
pub_counts_new = pub_counts[pub_counts >= 10]
pub_counts_new
# Out:
# Metadata.Publishers
# EA            165
# Ubisoft        92
# Activision     87
# Nintendo       85
# Sega           75
# THQ            61
# Sony           60
# 2K             49
# Konami         47
# Capcom         35
# Namco          33
# SquareEnix     31
# Midway         23
# Eidos          22
# Microsoft      21
# Atari          20
# Rockstar       12
# Disney         10
# Name: count, dtype: int64

# %%
top_pub_counts = pub_counts_new.index
top_pub_counts
# Out:
# Index(['EA', 'Ubisoft', 'Activision', 'Nintendo', 'Sega', 'THQ', 'Sony', '2K',
#        'Konami', 'Capcom', 'Namco', 'SquareEnix', 'Midway', 'Eidos',
#        'Microsoft', 'Atari', 'Rockstar', 'Disney'],
#       dtype='object', name='Metadata.Publishers')

# %%
df = df[df['Metadata.Publishers'].isin(top_pub_counts)]
df.shape[0]
# Out:
# 928

# %% [markdown]
# In the code above, we removed all publishers in the dataset, that did not have a value count of more than 10, this was done, to only include notable publishers to better help our analysis, and not have multiple publishers with low value counts, who could maybe cause our analysis to weaken.
#
# We dropped 20 more rows

# %%
sns.boxplot(x = "Features.Max Players", y = "Length.Main Story.Average", data = df)
# Out:
# <Axes: xlabel='Features.Max Players', ylabel='Length.Main Story.Average'>

# %%
sns.scatterplot(x = "Features.Max Players", y = "Length.Main Story.Average", data = df)
# Out:
# <Axes: xlabel='Features.Max Players', ylabel='Length.Main Story.Average'>

# %%
df = df[df['Features.Max Players'] < 8]
df = df[df['Length.Main Story.Average'] < 50]
df = df[df['Metadata.Publishers'] != "Capcom"]
sns.scatterplot(x = "Features.Max Players", y = "Length.Main Story.Average", data = df)
# Out:
# <Axes: xlabel='Features.Max Players', ylabel='Length.Main Story.Average'>

# %%
df.shape[0]
# Out:
# 883

# %% [markdown]
# Lets discuss the three graphs above.
#
# In the first graph, this is a boxplot, that compares our two numerical explanatory varaibles, "Max Players" and "Story Length Average", in this graph, for every max player count, it gave a boxplot, and as we can see there are a couple of outliers, the main ones being above "50" so when we start to think about removing some of them, data points above 50, may be gone
#
# In the second graph, we used a scatterplot, and this gives us a better sense of the data, as it uses each induvidual point. The first thing I see, which I could not really tell from the boxplot is that there is only game, with a max players of 8, and becuase of this, we may actually want to remove this, along with all data points above 50.
#
# Lastly in the third graph, we decided to remove the game with a Max of 8 players, and all data points above 50, this gives us a better looking data set, with no extreme outliers.
#
# When I was cleaning the data, there were no other data cleaning techniques I found useful, other than the ones I used, to help clean the data further.
#
# Note: I wanted to keep some of the outliers in the dataset, as it can give us a better sense of the data, removing all of them will result in the new dataframe not being representative of the original dataframe.
#
# We ended up dropping 11 more rows

# %% [markdown]
# ## 4. <u>Research Question</u>: How does the nature of the relationship between 'Max Players' and 'Length of the main story' change for different values of 'publishers' in the dataset??

# %%
plt.figure(figsize=(20, 10))
plt.title("Relationship between Max Players and Length of the main story")
sns.scatterplot(x = 'Features.Max Players', y = 'Length.Main Story.Average', hue = "Metadata.Publishers", data = df)
plt.show()

# %%
sns.lmplot(x = 'Features.Max Players', y = 'Length.Main Story.Average',hue = "Metadata.Publishers", data = df)
plt.title("Relationship between Max Players and Length of the main story")
plt.show()

# %%
df[['Metadata.Publishers', 'Length.Main Story.Average', 'Features.Max Players']].groupby(['Metadata.Publishers']).corr()
# Out:
#                                                Length.Main Story.Average  \
# Metadata.Publishers
# 2K                  Length.Main Story.Average                   1.000000
#                     Features.Max Players                       -0.023091
# Activision          Length.Main Story.Average                   1.000000
#                     Features.Max Players                        0.177334
# Atari               Length.Main Story.Average                   1.000000
#                     Features.Max Players                       -0.110089
# Disney              Length.Main Story.Average                   1.000000
#                     Features.Max Players                        0.140188
# EA                  Length.Main Story.Average                   1.000000
#                     Features.Max Players                       -0.082145
# Eidos               Length.Main Story.Average                   1.000000
#                     Features.Max Players                       -0.115709
# ...

# %% [markdown]
# The relationship between the length of the main story and the max number of players for every company except, Activision, Disney, Namco and SquareEnix, had a negative relationship
#
# The shape between the length of the main story and the max number of players for all publishers is linear
#
# The strength of the relatinship between the length of the main story and the max number of players varies greatly depending on the publisher. Here is a list of every company and their correlation between the length of the main story and the max number of player.
#
# Microsoft - -0.452
# Rockstar - -0.426
# Namco - 0.263
# Sony - -0.208
# Ubisoft - -0.196
# Midway - -0.181
# Activision - 0.177
# THQ - -0.170
# Disney - 0.140
# Konami - -0.121
# Nintendo - -0.119
# Eidos - -0.116
# Atari - -0.110
# EA - -0.082
# SquareEnix - 0.054
# 2K - -0.023
# Sega - -0.004
#
# As we can see there are only two companies with moderalty high correlations. Microsoft and Rockstar, this basically means as the max number of players decreases the average time it takes to complete the main story increases. Since these two companies have a correlation of about 0.4ish, this means it has moderately negative linear relationship.
#
# Companies other than these 2, have such low correlations where we can not accuratley make a judgement that would be somewhat concise. For example Sony, Ubisoft Midway etc, have values of -0.2 and -0.1. These correlation values are really low, and even though they are negative suggesting some form of "decrease in players = increase time to complete story" these values are not high correlation factors at all, meaning there is little to no linear relationship in the data.
#
# Note that there are companies with positive correlation values such as Activision, Disney, Namco, and SquareEnix however there values are low as well, coming in at 0.177, 0.14, 0.263 and 0.054 respectively. (A positive correlation means that as the max number of players increase, avg time to complete the main story also increases.) Due to the fact that these value are so low, we cant really say they are good r values, and are good measurements of linear relationship of the length of the main story and the max number of players.
#
# In term of outliers there are a couple outliers for every single number in Max Players however, I decided to keep some of the outliers, otherwise the cleaned data would not be representative of the original data we collected
#
# The slopes of every company but 4, where positive, and those companies where - Activision, Disney, Namco, and SquareEnix - every other slope was negative. However two companies had decently steep slopes, those where Microsoft and Rockstar, with slopes of -0.452 and -0.426 respectively.
#
# Research Question Re-Stated: "How does the nature of the relationship between 'Max Players' and 'Length of the main story' change for different values of 'publishers' in the dataset?"

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# SUMMARY OF FINDINGS:
#
# To summarize the final conclusions of my research findings, the results of trying to find: how does the nature of the relationship between 'Max Players' and 'Length of the main story' change for different values of 'publishers' in the dataset? Is very varied, but we did get a couple conclusive answers.
#
# For most game companies such as Sega, Sony, SquareEnix, etc the correlation between Max Players and Length of Story dependent on publisher was very low, mostly in the ranges of 0 - 0.2. However there where two companies that somewhat stood above the rest, and this was Microsoft and Rockstar. With correlations in the 0.4's. So what does all of this mean?
#
# If you are a fan of either Microsoft games or Rockstar games, this means that there is a negative moderate Linear relationship between the max amount of players in the game, and the time it takes to complete the main story. In short, when the number of max players decrease the amount of time it takes to complete the main game increases. So people who are really interested in games with a long fleshed out main story, should look into microsoft or rockstar games with low Max Players. The same can be said in an oppisite way about people who want games with a short main story but a high max player count
#
# SHORTCOMINGS:
#
# One main shortcoming was that, I might have included too many outliers in the data which may have skewed the results. There were so many outliers that were very subtle, or all packed ticghtly together with non outlier values, that it was really hard to diffrentiate between what was an outlier and what was not. Im glad I was able to find at least 2 companies (Microsoft and Rockstar) who could give us somewhat of a linear relationship between the variables (Max Players, Length of Main Story)
#
# FUTURE:
#
# For future analysis I will try to make sure to remove way more outliers, and maybe try not to be too focused on getting a datset that might not represent the original dataset. I might also change the varaible types, and have my z or my y be numerical and categroical respectively
